# %% [markdown]
# # WQD7005 - Data Mining
# ## Continuous Assessment
# ## Milestone 2

# %% [markdown]
# #### Matrix Number : 17043640
#
# #### Name                 : Gunasegarran Magadevan

# %% [markdown]
# ### Insight of extracted data

# %%
#importing libraries
import csv

# %%
#Importing oilCrawl
with open('../../Milestone1/oilCrawl/oilCrawl.csv', 'r') as oilCrawl:
    oilCrawlReader = csv.reader(oilCrawl)
    for row in oilCrawlReader:
        print(row)
# Out:
# ['No', 'Year', 'AverageClosing Price', 'Year Open', 'Year High', 'Year Low', 'Year Close', 'Annual% Change']
# ['0', '2020', '$50.73', '$61.18', '$63.27', '$28.93', '$28.93', '-52.62%']
# ['1', '2019', '$57.05', '$46.54', '$66.30', '$46.54', '$61.06', '34.46%']
# ['2', '2018', '$64.90', '$60.37', '$76.41', '$42.53', '$45.41', '-24.84%']
# ['3', '2017', '$50.84', '$52.33', '$60.42', '$42.53', '$60.42', '12.47%']
# ['4', '2016', '$43.58', '$36.76', '$54.06', '$26.21', '$53.72', '45.03%']
# ['5', '2015', '$48.72', '$52.72', '$61.43', '$34.73', '$37.04', '-30.70%']
# ['6', '2014', '$93.17', '$95.14', '$107.95', '$53.45', '$53.45', '-45.55%']
# ['7', '2013', '$97.98', '$93.14', '$110.62', '$86.65', '$98.17', '6.90%']
# ['8', '2012', '$94.05', '$102.96', '$109.39', '$77.72', '$91.83', '-7.08%']
# ['9', '2011', '$94.88', '$91.59', '$113.39', '$75.40', '$98.83', '8.15%']
# ['10', '2010', '$79.48', '$81.52', '$91.48', '$64.78', '$91.38', '15.10%']
# ...

# %%
#Importing goldCrawler
with open('../../Milestone1/goldCrawler/goldRate.csv', 'r') as goldCrawler:
    goldCrawlerReader = csv.reader(goldCrawler)
    for row in goldCrawlerReader:
        print(row)
# Out:
# ['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Change %']
# ['Mar 20', '1,502.50', '1,587.05', '1,703.90', '1,451.00', '1.72K', '-4.10%']
# ['Feb 20', '1,566.70', '1,597.80', '1,691.70', '1,551.10', '7.43M', '-1.34%']
# ['Jan 20', '1,587.90', '1,527.50', '1,619.60', '1,526.00', '2.15M', '4.50%']
# ['Dec 19', '1,519.50', '1,462.80', '1,523.40', '1,453.30', '12.30K', '3.68%']
# ['Nov 19', '1,465.60', '1,511.00', '1,511.60', '1,447.10', '97.34K', '-3.03%']
# ['Oct 19', '1,511.40', '1,468.70', '1,518.20', '1,458.30', '4.81K', '3.12%']
# ['Sep 19', '1,465.70', '1,522.90', '1,553.20', '1,463.50', '9.50K', '-3.52%']
# ['Aug 19', '1,519.10', '1,411.30', '1,549.30', '1,400.90', '14.45K', '6.52%']
# ['Jul 19', '1,426.10', '1,386.60', '1,444.20', '1,382.80', '77.78K', '1.16%']
# ['Jun 19', '1,409.70', '1,307.00', '1,433.30', '1,307.00', '5.27K', '7.96%']
# ['May 19', '1,305.80', '1,278.70', '1,306.40', '1,266.60', '58.75K', '1.79%']
# ...

# %%
#Importing currencyCrawl
with open('../../Milestone1/currencyCrawl/currencyExchange.csv', 'r') as currencyCrawl:
    currencyCrawlReader = csv.reader(currencyCrawl)
    for row in currencyCrawlReader:
        print(row)
# Out:
# ['Date', 'Price', 'Open', 'High', 'Low', 'Change %']
# ['Mar 20', '4.3505', '4.2125', '4.3505', '4.1595', '3.25%']
# ['Feb 20', '4.2135', '4.0975', '4.2435', '4.0965', '2.87%']
# ['Jan 20', '4.0960', '4.0890', '4.1120', '4.0510', '0.13%']
# ['Dec 19', '4.0905', '4.1775', '4.1815', '4.0895', '-2.06%']
# ['Nov 19', '4.1765', '4.1765', '4.1865', '4.1215', '-0.05%']
# ['Oct 19', '4.1785', '4.1880', '4.1980', '4.1730', '-0.20%']
# ['Sep 19', '4.1870', '4.2120', '4.2265', '4.1620', '-0.44%']
# ['Aug 19', '4.2055', '4.1375', '4.2295', '4.1355', '1.91%']
# ['Jul 19', '4.1265', '4.1315', '4.1455', '4.1035', '-0.15%']
# ['Jun 19', '4.1325', '4.1925', '4.1925', '4.1315', '-1.38%']
# ['May 19', '4.1905', '4.1315', '4.2015', '4.1305', '1.35%']
# ['Apr 19', '4.1345', '4.0835', '4.1475', '4.0725', '1.27%']
# ['Mar 19', '4.0825', '4.0725', '4.0975', '4.0555', '0.39%']
# ['Feb 19', '4.0665', '4.0855', '4.1065', '4.0605', '-0.72%']
# ['Jan 19', '4.0960', '4.1320', '4.1490', '4.0860', '-0.88%']
# ...
